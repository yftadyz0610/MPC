# %% [markdown]
#     Use CAL to find the most contrastive examples for annotation.

# %%
# Label
# 0: Physical
# 1: Mental

# %% [markdown]
# # Load Environment

# %%
'''
To use nltk's wordnet, you should download WordNet from https://www.nltk.org/nltk_data/ and then unzip wordnet.zip
under your home directory with path as /home_path/nltk_data/corpora/

'''
from nltk.corpus import wordnet as wn
import pandas as pd
import numpy as np
import tqdm
from collections import defaultdict
import joblib
import time
import json

from cal import cal

# %%
# we use fasttext embedding vector to represent word
# As 'cc.en.300.bin' is very large, it is not included in the submission. Download URL: https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.en.300.bin.gz
# Check more details in website: https://fasttext.cc/docs/en/crawl-vectors.html

import fasttext as ft
fast_model=ft.load_model('source/cc.en.300.bin')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
adj=pd.read_csv('Data/adj.csv') # load extracted adjectives from `high_entropy.ipynb`
adj.shape
# Out:
# (7292, 4)

# %% [markdown]
# # Build TestSet

# %%
testset=pd.read_csv('Data/test.csv')

# %% [markdown]
# # CAL

# %% [markdown]
#     All labeling steps below are implemented by two persons. If the labeling results disagree, we ask a third person to arbitrate.
#
#     In iteration T, for each word in `unlabeled_words`, nearest `neighK` neighbors in `labeled_words` are found
#     to compute KL divergence between predicted probabilities. Thus each word in `unlabeled_words` is associated
#     with a scalar. By sorting with descending order, `acq_size` number of words are selected for annotation as most contrastive samples.

# %%
acq_size=120 
neighK=10

# %%
# candidate words are from all valid adjectives except testset
adj_cand=[]
for w in adj['word']:
    if w not in testset['word']:
        adj_cand.append(w)

# %% [markdown]
# ## Iter1

# %% [markdown]
# ### Setup

# %%
# Randomly annotate some positive and negative words for training. Proportion of samples, 1:1
# `desc`: `physical` adj, describe physical attributes
# `opin`: `mental` adj, usually relates to mental attributes

desc=['anemic','arranged','assorted','available','baked','bitter','black','blue','broken','cherry',
      'citric','corrugated','commercial','cooked','crispy','crushed','crusty','decorative','dietetic',
     'digestible','dried','drippy','edible','empty','fake']
opin=['amazing','awesome','awful','aware','bad','basic','beneficial','best','bold','bothersome','careful',
      'casual','certain','cheap','clean','clear','cold','comfortable','common','comparable','competitive',
     'complete','consistent','contributive','convenient','conventional','cool','costly','crazy']

# %%
word_type='adj'
trainset=[]
        
for w in desc:
    defn=adj.loc[adj.word==w,'text'].values[0]
    trainset.append((w,defn,0)) # 0: physical
    
for w in opin:
    defn=adj.loc[adj.word==w,'text'].values[0]
    trainset.append((w,defn,1)) # 1: mental

# %%
train=pd.DataFrame()
train['word'],train['text'],train['target']=list(zip(*(trainset)))

# %%
train.to_csv('Data/train.v8.1.round1.csv')

# %% [markdown]
# ### Contrastives

# %% [markdown]
#     We use the trained model to make predictions over all valid adjectives. The output probability is used in finding contrastive samples.

# %%
pred=joblib.load('Data/pred.v8.1.round1') # load prediction result
assert pred.shape[0]==adj.shape[0]

labeled_words=train['word'].tolist()
w_prob_map={}
for i,w in enumerate(adj['word'].tolist()):
    w_prob_map[w]=[1-pred[i].item(),pred[i].item()]
unlabeled_words=[ w for w in adj['word'].tolist() if w not in labeled_words]
cs=cal(labeled_words, unlabeled_words, acq_size, w_prob_map, neighK , fast_model)

# %%
for w,kl in cs:
    
    print(w)
    print(adj.loc[adj.word==w,'text'].values[0]) # check definition
    print('\n')
# Out:
# apoplectic
# pertaining to or characteristic of apoplexy
#
#
# psychotic
# characteristic of or suffering from psychosis
#
#
# arthritic
# of or pertaining to arthritis
#
#
# crispiest
# tender and brittle
#
#
# impeccable
# without fault or error; not capable of sin
#
#
# gluttonous
# given to excess in consumption of especially food or drink
#
#
# greasier
# containing an unusual amount of grease or oil; smeared or soiled with grease or oil
#
#
# chronological
# relating to or arranged according to temporal order
#
#
# damned
# expletives used informally as intensifiers; in danger of the eternal punishment of Hell
#
#
# addictive
# causing or characterized by addiction
#
#
# strep
# of or relating to or caused by streptococci
#
#
# demented
# affected with madness or insanity
#
#
# instinct
# (followed by `with')deeply filled or permeated
#
#
# tragic
# very sad; especially involving grief or death or destruction; of or relating to or characteristic of tragedy
#
#
# schizophrenic
# suffering from some form of schizophrenia; of or relating to or characteristic of schizophrenia
#
#
# creamiest
# of the color of cream; thick like cream
#
#
# adulterate
# mixed with impurities
#
#
# separable
# capable of being divided or dissociated
#
#
# lunatic
# insane and believed to be affected by the phases of the moon
#
#
# irreversible
# incapable of being reversed
#
#
# autistic
# characteristic of or affected with autism
#
#
# greasiest
# containing an unusual amount of grease or oil; smeared or soiled with grease or oil
#
#
# logistical
# of or relating to logistics
#
#
# scorching
# hot and dry enough to burn or parch a surface
#
#
# olfactive
# of or relating to olfaction
#
#
# menopausal
# of or relating to the menopause
#
#
# rastafarian
# of or pertaining to or characteristic of Rastafarianism or Rastafarians
#
#
# hypoglycemic
# of or relating to hypoglycemia
#
#
# capsulated
# used of seeds or spores that are enclosed in a capsule
#
#
# breathtaking
# tending to cause suspension of regular breathing
#
#
# hormonal
# of or relating to or caused by hormones
#
#
# thyroid
# of or relating to the thyroid gland; suggestive of a thyroid disorder
#
#
# nauseating
# causing or able to cause nausea
#
#
# impassable
# incapable of being passed
#
#
# anaphylactic
# related to the hypersensitivity known as anaphylaxis
#
#
# irrelevant
# having no bearing on or connection with the subject at issue
#
#
# premenstrual
# of or relating to or occurring during the period just before menstruation
#
#
# full-term
# gestated for the entire duration of normal pregnancy
#
#
# extendable
# capable of being lengthened
#
#
# erroneous
# containing or characterized by error
#
#
# sickening
# causing or able to cause nausea
#
#
# participial
# of or relating to or consisting of participles
#
#
# fattier
# containing or composed of fat
#
#
# frothing
# producing or covered with lathery sweat or saliva from exhaustion or disease
#
#
# invariable
# not liable to or capable of change
#
#
# unpopular
# regarded with disfavor or lacking general approval
#
#
# ulcerative
# of or relating to or characterized by ulceration
#
#
# chemotherapeutic
# of or relating to chemotherapy
#
#
# metastatic
# relating to or affected by metastasis
#
#
# tidal
# of or relating to or caused by tides
#
#
# estrogenic
# relating to or caused by estrogen
#
#
# lupine
# of or relating to or characteristic of wolves
#
#
# asthmatic
# relating to breathing with a whistling sound
#
#
# indigestible
# digested with difficulty
#
#
# salivary
# of or relating to saliva
#
#
# lethal
# of an instrument of certain death
#
#
# menstrual
# of or relating to menstruation or the menses
#
#
# eosinophilic
# of or relating to eosinophil
#
#
# drug-free
# characteristic of a person not taking illegal drugs or of a place where no illegal drugs are used
#
#
# contagious
# easily diffused or spread as from one person to another; (of disease) capable of being transmitted by infection
#
#
# inexcusable
# without excuse or justification; not excusable
#
#
# habit-forming
# causing or characterized by addiction
#
#
# staphylococcal
# of or relating to the staphylococcus bacteria
#
#
# formulary
# of or relating to or of the nature of a formula
#
#
# epileptic
# of or relating to or characteristic of epilepsy
#
#
# neurotic
# characteristic of or affected by neurosis; affected with emotional disorder
#
#
# draining
# having a debilitating effect
#
#
# cannibalistic
# characteristic of cannibals or exhibiting cannibalism
#
#
# bacterial
# relating to or caused by bacteria
#
#
# excretory
# of or relating to the process of excretion
#
#
# gestational
# of or relating to gestation
#
#
# olfactory
# of or relating to olfaction
#
#
# well-adjusted
# free from psychological disorder
#
#
# microbial
# of or involving or caused by or being microbes
#
#
# slimed
# covered with or resembling slime
#
#
# testicular
# of or involving the testes
#
#
# gastroesophageal
# of or relating to or involving the stomach and esophagus
#
#
# daft
# informal or slang terms for mentally irregular
#
#
# cardiovascular
# of or pertaining to or involving the heart and blood vessels
#
#
# cruddy
# characterized by obscenity
#
#
# proletarian
# belonging to or characteristic of the proletariat
#
#
# foolproof
# not liable to failure
#
#
# disgusted
# having a strong distaste from surfeit
#
#
# god-awful
# very unpleasant
#
#
# spacey
# stupefied by (or as if by) some narcotic drug
#
#
# caloric
# relating to or associated with heat; of or relating to calories in food
#
#
# idiopathic
# (of diseases) arising from an unknown cause
#
#
# catatonic
# characterized by catatonia especially either rigidity or extreme laxness of limbs
#
#
# degenerative
# (of illness) marked by gradual deterioration of organs and cells along with loss of function
#
#
# poorly
# somewhat ill or prone to illness
#
#
# narcoleptic
# of or relating to narcolepsy
#
#
# dejected
# affected or marked by low spirits
#
#
# bumpier
# causing or characterized by jolts and irregular movements; covered with or full of bumps
#
#
# viral
# relating to or caused by a virus
#
#
# smokiest
# marked by or emitting or filled with smoke; tasting of smoke
#
#
# aleutian
# of or relating to the Aleut or their language or culture
#
#
# segregated
# separated or isolated from others or a main group
#
#
# colonic
# of or relating to the colon
#
#
# hemolytic
# relating to or involving or causing hemolysis
#
#
# paranoid
# suffering from paranoia
#
#
# metabolic
# of or relating to metabolism; undergoing metamorphosis
#
#
# smokier
# marked by or emitting or filled with smoke; tasting of smoke
#
#
# one-man
# designed for or restricted to a single person
#
#
# one-woman
# designed for or restricted to a single person
#
#
# sweltering
# excessively hot and humid or marked by sweating and faintness
#
#
# awash
# covered with water
#
#
# precancerous
# of or relating to a growth that is not malignant but is likely to become so if not treated
#
#
# serous
# of or producing or containing serum
#
#
# rheumatoid
# of or pertaining to arthritis
#
#
# sebaceous
# containing an unusual amount of grease or oil
#
#
# reflex
# without volition or conscious control
#
#
# catabolic
# relating to or characterized by catabolism; characterized by destructive metabolism
#
#
# pancreatic
# of or involving the pancreas
#
#
# unpardonable
# not admitting of pardon
#
#
# allergic
# characterized by or caused by allergy; having an allergy or peculiar or excessive susceptibility (especially to a specific factor)
#
#
# intestinal
# of or relating to or inside the intestines
#
#
# gustatorial
# of or relating to gustation
#
#
# calculating
# used of persons
#
#
# requisite
# necessary for relief or supply
#
#
# asinine
# devoid of intelligence

# %% [markdown]
# ## Iter2

# %% [markdown]
# ### Setup

# %%
# pick 20-20 words from annotation result of the most contrastive samples.

desc2=['apoplectic','arthritic','crispiest','greasier','chronological','strep','creamiest','adulterate','separable',
       'logistical','scorching','olfactive','menopausal','hypoglycemic','capsulated','breathtaking','hormonal',
       'thyroid','impassable','anaphylactic','premenstrual']

opin2=['psychotic','impeccable','gluttonous','damned','addictive','demented','tragic','schizophrenic','lunatic',
       'irreversible','autistic','greasiest','nauseating','irrelevant','erroneous','sickening','invariable',
       'unpopular']


# If any word exists in testset, delete it and resample.
for w in desc2+opin2:
    if w in testset['word']:
        print(w)

desc_all=desc+desc2
opin_all=opin+opin2

    
word_type='adj'
trainset=[]
for w in desc_all:
    defn=adj.loc[adj.word==w,'text'].values[0]
    trainset.append((w,defn,0)) # 0: physical
for w in opin_all:
    defn=adj.loc[adj.word==w,'text'].values[0]
    trainset.append((w,defn,1)) # 1: mental
    
    
train2=pd.DataFrame()
train2['word'],train2['text'],train2['target']=list(zip(*(trainset)))

train2.to_csv('Data/train.v8.2.round2.csv')

# %% [markdown]
#     Training is done by `train_cal.py`. Remember setting Config.is_predict=False before training.

# %% [markdown]
# ### Evaluate

# %%
pred=joblib.load('Data/pred.v8.2.round2') # load prediction result
assert pred.shape[0]==adj.shape[0]

# testset performance

pred_dict={}
for i,w in enumerate(adj['word'].tolist()):
    pred_dict[w]=pred[i]
    
    
testset['pred_score']=testset['word'].apply(lambda x: pred_dict[x])
testset['pred_label']=testset['pred_score'].apply(lambda x: 1 if x>0.5 else 0)

# positive::precision
print("positive::precision %.3f"%(testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.pred_label==1)].shape[0]))
print("positive::recall %.3f"%(testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.target==1)].shape[0]))


print("negative::precision %.3f"%(testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.pred_label==0)].shape[0]))
print("negative::recall %.3f"%(testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.target==0)].shape[0]))

pp=testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.pred_label==1)].shape[0]
pr=testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.target==1)].shape[0]

print("F1: %.2f"%(2*pp*pr/(pp+pr)))


np=testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.pred_label==0)].shape[0]
nr=testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.target==0)].shape[0]

print("N F1: %.2f"%(2*np*nr/(np+nr)))
# Out:
# positive::precision 0.476
# positive::recall 0.833
# negative::precision 0.838
# negative::recall 0.484
# F1: 0.61
# N F1: 0.61

# %% [markdown]
# ## Iter3

# %% [markdown]
# ### Setup

# %%
pred=joblib.load('Data/pred.v8.2.round2') # load prediction result
assert pred.shape[0]==adj.shape[0]

labeled_words=train2['word'].tolist()
w_prob_map={}
for i,w in enumerate(adj['word'].tolist()):
    w_prob_map[w]=[1-pred[i].item(),pred[i].item()]
unlabeled_words=[ w for w in adj['word'].tolist() if w not in labeled_words]
cs=cal(labeled_words, unlabeled_words, acq_size, w_prob_map, neighK , fast_model)

# %%
for w,kl in cs:
    
    print(w)
    print(adj.loc[adj.word==w,'text'].values[0])
    print('\n')
# Out:
# cardiovascular
# of or pertaining to or involving the heart and blood vessels
#
#
# cerebrovascular
# of or relating to the brain and the blood vessels that supply it
#
#
# gravitational
# of or relating to or caused by gravitation
#
#
# ergonomic
# of or relating to ergonomics
#
#
# gustatorial
# of or relating to gustation
#
#
# laryngopharyngeal
# of or relating to the larynx and pharynx
#
#
# inertial
# of or relating to inertia
#
#
# multicultural
# of or relating to or including several cultures
#
#
# formulary
# of or relating to or of the nature of a formula
#
#
# gastroesophageal
# of or relating to or involving the stomach and esophagus
#
#
# futuristic
# of or relating to futurism
#
#
# translational
# of or relating to uniform movement without rotation
#
#
# behavioral
# of or relating to behavior
#
#
# epidemiological
# of or relating to epidemiology
#
#
# areal
# of or relating to or involving an area
#
#
# rotational
# of or pertaining to rotation
#
#
# colloidal
# of or relating to or having the properties of a colloid
#
#
# gynecological
# of or relating to or practicing gynecology
#
#
# narcoleptic
# of or relating to narcolepsy
#
#
# endothelial
# of or relating to or located in the endothelium
#
#
# graduate
# of or relating to studies beyond a bachelor's degree
#
#
# organizational
# of or relating to an organization
#
#
# ulcerative
# of or relating to or characterized by ulceration
#
#
# nutritional
# of or relating to or providing nutrition
#
#
# aleutian
# of or relating to the Aleut or their language or culture
#
#
# dermatological
# of or relating to or practicing dermatology
#
#
# staphylococcal
# of or relating to the staphylococcus bacteria
#
#
# tutorial
# of or relating to tutors or tutoring
#
#
# curricular
# of or relating to an academic course of study
#
#
# cartilaginous
# of or relating to cartilage; difficult to chew
#
#
# mediterranean
# of or relating to or characteristic of or located near the Mediterranean Sea
#
#
# skeletal
# of or relating to or forming or attached to a skeleton; very thin especially from disease or hunger or cold
#
#
# laotian
# of or relating to Laos or its people
#
#
# precancerous
# of or relating to a growth that is not malignant but is likely to become so if not treated
#
#
# pediatric
# of or relating to the medical care of children
#
#
# demographic
# of or relating to demography
#
#
# senegalese
# of or relating to or characteristic of Senegal or its people
#
#
# doctoral
# of or relating to a doctor or doctorate
#
#
# subtropical
# of or relating to or characteristic of conditions in the subtropics
#
#
# indonesian
# of or relating to or characteristic of Indonesia or its people or languages
#
#
# nitrogenous
# of or relating to or containing nitrogen
#
#
# endoscopic
# of or relating to endoscopy
#
#
# philippine
# of or relating to or characteristic of the Philippines or its people or customs
#
#
# toxicological
# of or relating to toxicology
#
#
# eosinophilic
# of or relating to eosinophil
#
#
# biochemical
# of or relating to biochemistry; involving chemical processes in living organisms
#
#
# prospective
# of or concerned with or related to the future
#
#
# veterinary
# of or relating to veterinarians or veterinary medicine
#
#
# polish
# of or relating to Poland or its people or culture
#
#
# myocardial
# of or relating to the myocardium
#
#
# microbial
# of or involving or caused by or being microbes
#
#
# gestational
# of or relating to gestation
#
#
# czechoslovakian
# of or relating to Czechoslovakia or its people or their language
#
#
# orthodontic
# of or relating to or involving or practicing orthodontics
#
#
# transitional
# of or relating to or characterized by transition
#
#
# hebridean
# of or relating to the Hebrides
#
#
# balsamic
# of or relating to or containing balsam
#
#
# paleolithic
# of or relating to the second period of the Stone Age (following the eolithic)
#
#
# physiological
# of or relating to the biological study of physiology; of or consistent with an organism's normal functioning
#
#
# covalent
# of or relating to or characterized by covalence
#
#
# paraguayan
# of or relating to or characteristic of Paraguay or its people
#
#
# administrative
# of or relating to or responsible for administration
#
#
# long-distance
# of or relating to or being a long-distance telephone call; covering a long distance
#
#
# gastrointestinal
# of or relating to the stomach and intestines
#
#
# cruciferous
# of or relating to or belonging to the plant family Cruciferae
#
#
# developmental
# of or relating to or constituting development
#
#
# pancreatic
# of or involving the pancreas
#
#
# lebanese
# of or relating to or characteristic of Lebanon or its people
#
#
# aerodynamic
# of or relating to aerodynamics; designed or arranged to offer the least resistant to fluid flow
#
#
# pharmaceutical
# of or relating to pharmacy or pharmacists; of or relating to drugs used in medical treatment
#
#
# olfactory
# of or relating to olfaction
#
#
# homeopathic
# of or relating to the practice of homeopathy
#
#
# australian
# of or relating to or characteristic of Australia or its inhabitants or its languages
#
#
# provencal
# of or relating to Provence or its people or their culture
#
#
# italian
# of or pertaining to or characteristic of Italy or its people or culture or language
#
#
# dental
# of or relating to the teeth; of or relating to dentistry
#
#
# motivational
# of or relating to motivation
#
#
# korean
# of or relating to or characteristic of Korea or its people or language
#
#
# departmental
# of or relating to a department
#
#
# neurological
# of or relating to or used in or practicing neurology
#
#
# excretory
# of or relating to the process of excretion
#
#
# enzymatic
# of or relating to or produced by an enzyme
#
#
# statistical
# of or relating to statistics
#
#
# rastafarian
# of or pertaining to or characteristic of Rastafarianism or Rastafarians
#
#
# iranian
# of or relating to Iran or its people or language or culture
#
#
# menstrual
# of or relating to menstruation or the menses
#
#
# pneumatic
# of or relating to or using air (or a similar gas)
#
#
# orthopedic
# of or relating to orthopedics
#
#
# evolutionary
# of or relating to or produced by evolution
#
#
# pharmacological
# of or relating to pharmacology
#
#
# macrobiotic
# of or relating to the theory or practice of macrobiotics
#
#
# quarterly
# of or relating to or consisting of a quarter
#
#
# gastronomic
# of or relating to gastronomy
#
#
# antibiotic
# of or relating to antibiotic drugs
#
#
# jewish
# of or relating to Jews or their culture or religion
#
#
# chemotherapeutic
# of or relating to chemotherapy
#
#
# instructional
# of or relating to or used in instruction
#
#
# propagandist
# of or relating to or characterized by propaganda
#
#
# toxic
# of or relating to or caused by a toxin or poison
#
#
# mammalian
# of or relating to the class Mammalia
#
#
# einsteinian
# of or relating to Albert Einstein or his theories
#
#
# generational
# of or relating to a generation
#
#
# darwinian
# of or relating to Charles Darwin's theory of organic evolution
#
#
# occupational
# of or relating to the activity or business for which you are trained
#
#
# ethiopian
# of or relating to or characteristic of Ethiopia or its people or languages
#
#
# insecticidal
# of or relating to insecticide
#
#
# gravimetric
# of or relating to hydrometry
#
#
# numeric
# of or relating to or denoting numbers; measured or expressed in numbers
#
#
# shakespearean
# of or relating to William Shakespeare or his works
#
#
# neurologic
# of or relating to or used in or practicing neurology
#
#
# uruguayan
# of or relating to or characteristic of Uruguay or its people
#
#
# turkish
# of or relating to or characteristic of Turkey or its people or language
#
#
# ceylonese
# of or relating to Sri Lanka (formerly Ceylon) or its people or culture
#
#
# caucasian
# of or relating to the geographical region of Caucasia; of or relating to Caucasian people
#
#
# chitinous
# of or resembling chitin
#
#
# rheumatoid
# of or pertaining to arthritis
#
#
# day-to-day
# of or belonging to or occurring every day
#
#
# argentinian
# of or relating to or characteristic of Argentina or its people
#
#
# joined
# of or relating to two people who are married to each other; connected by a link, as railway cars or trailer trucks
#
#
# fecal
# of or relating to feces

# %%
# pick 20-20 words from annotation result of the most contrastive samples.

desc3=['cardiovascular','gravitational','ergonomic','gustatorial','laryngopharyngeal','inertial','formulary',
       'gastroesophageal','translational','behavioral','epidemiological','areal','rotational','colloidal',
       'gynecological','narcoleptic','endothelial','organizational','ulcerative','nutritional','dermatological']

opin3=['multicultural','futuristic','graduate','developmental','prospective']


# If any word exists in testset, delete it and resample.
for w in desc3+opin3:
    if w in testset['word']:
        print(w)

desc_all=desc+desc2+desc3
opin_all=opin+opin2+opin3

    
word_type='adj'
trainset=[]
for w in desc_all:
    defn=adj.loc[adj.word==w,'text'].values[0]
    trainset.append((w,defn,0)) # 0: physical
for w in opin_all:
    defn=adj.loc[adj.word==w,'text'].values[0]
    trainset.append((w,defn,1)) # 1: mental
    
    
train3=pd.DataFrame()
train3['word'],train3['text'],train3['target']=list(zip(*(trainset)))

train3.to_csv('Data/train.v8.3.round3.csv')

# %% [markdown]
# ### Evaluate

# %%
pred=joblib.load('Data/pred.v8.3.1.round3') # load prediction result
assert pred.shape[0]==adj.shape[0]

# testset performance

pred_dict={}
for i,w in enumerate(adj['word'].tolist()):
    pred_dict[w]=pred[i]
    
    
testset['pred_score']=testset['word'].apply(lambda x: pred_dict[x])
testset['pred_label']=testset['pred_score'].apply(lambda x: 1 if x>0.5 else 0)

# positive::precision
print("positive::precision %.3f"%(testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.pred_label==1)].shape[0]))
print("positive::recall %.3f"%(testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.target==1)].shape[0]))


print("negative::precision %.3f"%(testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.pred_label==0)].shape[0]))
print("negative::recall %.3f"%(testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.target==0)].shape[0]))

pp=testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.pred_label==1)].shape[0]
pr=testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.target==1)].shape[0]

print("F1: %.2f"%(2*pp*pr/(pp+pr)))

np=testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.pred_label==0)].shape[0]
nr=testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.target==0)].shape[0]

print("N F1: %.2f"%(2*np*nr/(np+nr)))
# Out:
# positive::precision 0.538
# positive::recall 0.778
# negative::precision 0.833
# negative::recall 0.625
# F1: 0.64
# N F1: 0.71

# %% [markdown]
# ###  RunTwoMore

# %% [markdown]
#     For another two runs, only show the prediction result over testset.

# %%
pred=joblib.load('Data/pred.v8.3.2.round3') # load prediction result
assert pred.shape[0]==adj.shape[0]

# testset performance

pred_dict={}
for i,w in enumerate(adj['word'].tolist()):
    pred_dict[w]=pred[i]
    
    
testset['pred_score']=testset['word'].apply(lambda x: pred_dict[x])
testset['pred_label']=testset['pred_score'].apply(lambda x: 1 if x>0.5 else 0)

# positive::precision
print("positive::precision %.3f"%(testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.pred_label==1)].shape[0]))
print("positive::recall %.3f"%(testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.target==1)].shape[0]))


print("negative::precision %.3f"%(testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.pred_label==0)].shape[0]))
print("negative::recall %.3f"%(testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.target==0)].shape[0]))

pp=testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.pred_label==1)].shape[0]
pr=testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.target==1)].shape[0]

print("F1: %.2f"%(2*pp*pr/(pp+pr)))

np=testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.pred_label==0)].shape[0]
nr=testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.target==0)].shape[0]

print("N F1: %.2f"%(2*np*nr/(np+nr)))
# Out:
# positive::precision 0.509
# positive::recall 0.750
# negative::precision 0.809
# negative::recall 0.594
# F1: 0.61
# N F1: 0.68

# %%
pred=joblib.load('Data/pred.v8.3.3.round3') # load prediction result
assert pred.shape[0]==adj.shape[0]

# testset performance

pred_dict={}
for i,w in enumerate(adj['word'].tolist()):
    pred_dict[w]=pred[i]
    
    
testset['pred_score']=testset['word'].apply(lambda x: pred_dict[x])
testset['pred_label']=testset['pred_score'].apply(lambda x: 1 if x>0.5 else 0)

# positive::precision
print("positive::precision %.3f"%(testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.pred_label==1)].shape[0]))
print("positive::recall %.3f"%(testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.target==1)].shape[0]))


print("negative::precision %.3f"%(testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.pred_label==0)].shape[0]))
print("negative::recall %.3f"%(testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.target==0)].shape[0]))

pp=testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.pred_label==1)].shape[0]
pr=testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.target==1)].shape[0]

print("F1: %.2f"%(2*pp*pr/(pp+pr)))

np=testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.pred_label==0)].shape[0]
nr=testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.target==0)].shape[0]

print("N F1: %.2f"%(2*np*nr/(np+nr)))
# Out:
# positive::precision 0.556
# positive::recall 0.694
# negative::precision 0.800
# negative::recall 0.688
# F1: 0.62
# N F1: 0.74

# %% [markdown]
# ## Iter4

# %% [markdown]
# ### Setup

# %%
pred=joblib.load('Data/pred.v8.3.1.round3') # load prediction result
assert pred.shape[0]==adj.shape[0]
labeled_words=train3['word'].tolist()

w_prob_map={}
for i,w in enumerate(adj['word'].tolist()):
    w_prob_map[w]=[1-pred[i].item(),pred[i].item()]
unlabeled_words=[ w for w in adj['word'].tolist() if w not in labeled_words]
cs=cal(labeled_words, unlabeled_words, acq_size, w_prob_map, neighK , fast_model)

# %%
for w,kl in cs:
    
    print(w)
    print(adj.loc[adj.word==w,'text'].values[0])
    print('\n')
# Out:
# toxic
# of or relating to or caused by a toxin or poison
#
#
# creamier
# of the color of cream; thick like cream
#
#
# nutritious
# of or providing nourishment
#
#
# lethal
# of an instrument of certain death
#
#
# traumatic
# of or relating to a physical injury or wound to the body; psychologically painful
#
#
# fishy
# of or relating to or resembling fish; not as expected
#
#
# motivational
# of or relating to motivation
#
#
# meteoric
# of or pertaining to atmospheric phenomena, especially weather and weather conditions; pertaining to or consisting of meteors or meteoroids; like a meteor in speed or brilliance or transience
#
#
# fishier
# of or relating to or resembling fish; not as expected
#
#
# tutorial
# of or relating to tutors or tutoring
#
#
# menial
# used of unskilled work (especially domestic work)
#
#
# murkier
# (of liquids) clouded as with sediment; dark or gloomy
#
#
# squashed
# that has been violently compressed
#
#
# gassier
# resembling gas; suffering from excessive gas in the alimentary canal
#
#
# bearable
# capable of being borne though unpleasant
#
#
# instructional
# of or relating to or used in instruction
#
#
# thrown
# caused to fall to the ground; twisted together; as of filaments spun into a thread
#
#
# woodier
# made of or containing or resembling wood; abounding in trees; made hard like wood as the result of the deposition of lignin in the cell walls
#
#
# creamy
# of the color of cream; thick like cream
#
#
# pavlovian
# of or relating to Ivan Pavlov or his experiments
#
#
# quarterly
# of or relating to or consisting of a quarter
#
#
# procurable
# capable of being obtained
#
#
# untold
# of an incalculable amount
#
#
# continental
# of or pertaining to or typical of Europe; of or relating to or concerning the American colonies during and immediately after the American Revolutionary War; of or relating to or characteristic of a continent; being or concerning or limited to a continent especially the continents of North America or Europe
#
#
# reptilian
# of or relating to the class Reptilia
#
#
# darwinian
# of or relating to Charles Darwin's theory of organic evolution
#
#
# buff
# of the yellowish-beige color of buff leather
#
#
# sundry
# consisting of a haphazard assortment of different kinds; ; ; ; ; ; - I.A.Richards
#
#
# statistical
# of or relating to statistics
#
#
# transitional
# of or relating to or characterized by transition
#
#
# sufficient
# of a quantity that can fulfill a need or requirement but without being abundant
#
#
# browner
# of a color similar to that of wood or earth; (of skin) deeply suntanned
#
#
# phonetic
# of or relating to speech sounds; of or relating to the scientific study of speech sounds
#
#
# departmental
# of or relating to a department
#
#
# singaporean
# of or relating to the island nation of Singapore and its people; of or relating to the city of Singapore
#
#
# takeout
# of or involving food to be taken and eaten off the premises
#
#
# shrimpy
# (used especially of persons) of inferior size
#
#
# orangish
# of the color between red and yellow; similar to the color of a ripe orange
#
#
# watered
# (of silk fabric) having a wavelike pattern
#
#
# growing
# relating to or suitable for growth
#
#
# tangential
# of superficial relevance if any; of or relating to or acting along or in the direction of a tangent
#
#
# ripened
# of wines, fruit, cheeses; having reached a desired or final condition; (`aged' pronounced as one syllable)
#
#
# litigious
# of or relating to litigation; inclined or showing an inclination to dispute or disagree, even to engage in law suits
#
#
# joined
# of or relating to two people who are married to each other; connected by a link, as railway cars or trailer trucks
#
#
# vestal
# of or relating to Vesta; in a state of sexual virginity
#
#
# golden-yellow
# of yellow tinged with gold
#
#
# lumpier
# like or containing small sticky lumps; having lumps; not smooth and even in texture
#
#
# murky
# (of liquids) clouded as with sediment; dark or gloomy
#
#
# god-awful
# very unpleasant
#
#
# extendable
# capable of being lengthened
#
#
# congealed
# congealed into jelly; solidified by cooling
#
#
# obtainable
# capable of being obtained
#
#
# nourishing
# of or providing nourishment
#
#
# sulphuric
# of or relating to or containing sulfur
#
#
# compounded
# combined into or constituting a chemical compound
#
#
# social
# relating to human society and its members; living together or enjoying life in communities or organized groups; relating to or belonging to or characteristic of high society; composed of sociable people or formed for the purpose of sociability; tending to move or live together in groups or colonies of the same kind; marked by friendly companionship with others
#
#
# ministerial
# of or relating to a minister of religion or the minister's office; of or relating to a government minister or ministry
#
#
# monthly
# of or occurring or payable every month
#
#
# hypnotic
# of or relating to hypnosis; attracting and holding interest as if by a spell
#
#
# reformed
# of or relating to the body of Protestant Christianity arising during the Reformation; used of some Protestant churches especially Calvinist as distinct from Lutheran; caused to abandon an evil manner of living and follow a good one
#
#
# yellow-orange
# of orange tinged with yellow
#
#
# manual
# of or relating to the hands; requiring human effort; doing or requiring physical work
#
#
# reddish-orange
# of orange tinged with red
#
#
# pinkish-orange
# of orange tinged with pink
#
#
# cartilaginous
# of or relating to cartilage; difficult to chew
#
#
# instinct
# (followed by `with')deeply filled or permeated
#
#
# dissolved
# (of solid matter) reduced to a liquid form
#
#
# underdone
# insufficiently cooked
#
#
# harsher
# unpleasantly stern; disagreeable to the senses; of textures that are rough to the touch or substances consisting of relatively large particles; unkind or cruel or uncivil; severe; sharply disagreeable; rigorous
#
#
# bridal
# of or relating to a wedding; of or pertaining to a bride
#
#
# top-notch
# of the highest quality
#
#
# minty
# relating to or suggestive of mint
#
#
# long-chain
# of molecules having relatively long chains of atoms in a molecule
#
#
# short-term
# relating to or extending over a limited period
#
#
# thin-shelled
# of animals or plants that have a thin shell
#
#
# evolutionary
# of or relating to or produced by evolution
#
#
# parasitic
# relating to or caused by parasites; of or pertaining to epenthesis; of plants or persons; having the nature or habits of a parasite or leech; living off another
#
#
# adjectival
# of or relating to or functioning as an adjective
#
#
# impacted
# wedged or packed in together
#
#
# crystalized
# (used especially of fruits) preserved by coating with or allowing to absorb sugar
#
#
# iconic
# relating to or having the characteristics on an icon
#
#
# skimmed
# used of milk and milk products from which the cream has been removed
#
#
# muskier
# resembling the smell of musk
#
#
# dissoluble
# capable of dissolving
#
#
# pitted
# pitted with cell-like cavities (as a honeycomb)
#
#
# demographic
# of or relating to demography
#
#
# phenomenal
# of or relating to a phenomenon; exceedingly or unbelievably great
#
#
# red-grey
# of grey tinged with red
#
#
# vegetative
# of or relating to an activity that is passive and monotonous; composed of vegetation or plants; relating to involuntary bodily functions; (of reproduction) characterized by asexual processes
#
#
# interstate
# involving and relating to the mutual relations of states especially of the United States
#
#
# mephitic
# of noxious stench from atmospheric pollution
#
#
# skim
# used of milk and milk products from which the cream has been removed
#
#
# muddied
# (of color) discolored by impurities; not bright and clear;  is often used in combination
#
#
# pronounceable
# capable of being uttered or pronounced
#
#
# shell-less
# of animals or fruits that have no shell
#
#
# semi-evergreen
# of a plant that is incompletely evergreen
#
#
# uppercase
# relating to capital letters which were kept in the top half of a compositor's type case
#
#
# peachy
# very good; of something resembling a peach in color
#
#
# aerodynamic
# of or relating to aerodynamics; designed or arranged to offer the least resistant to fluid flow
#
#
# pass
# of advancing the ball by throwing it
#
#
# evaporated
# drawn off in the form of vapor
#
#
# scummy
# of the most contemptible kind; covered with scum
#
#
# longtime
# of long duration
#
#
# circulatory
# of or relating to circulation; relating to circulatory system or to circulation of the blood
#
#
# yellowish
# of the color intermediate between green and orange in the color spectrum; of something resembling the color of an egg yolk
#
#
# drizzling
# (of rain) falling lightly in very small drops
#
#
# straw
# of a pale yellow color like straw; straw-colored
#
#
# crispier
# tender and brittle
#
#
# coarser
# of textures that are rough to the touch or substances consisting of relatively large particles; lacking refinement or cultivation or taste; of low or inferior quality or value; - Shakespeare
#
#
# narcotic
# of or relating to or designating narcotics; inducing stupor or narcosis; inducing mental lethargy
#
#
# nutritive
# of or providing nourishment
#
#
# dark-brown
# of a color similar to that of wood or earth
#
#
# cultivated
# (of land or fields) prepared for raising crops by plowing or fertilizing; no longer in the natural state; developed by human care and for human use; marked by refinement in taste and manners
#
#
# contractual
# relating to or part of a binding legal agreement
#
#
# generational
# of or relating to a generation
#
#
# crowded
# overfilled or compacted or concentrated
#
#
# communicative
# of or relating to communication; able or tending to communicate; - W.M.Thackeray
#
#
# suspended
# (of undissolved particles in a fluid) supported or kept from sinking or falling by buoyancy and without apparent attachment
#
#
# endogenous
# of or resembling an endogen; derived or originating internally
#
#
# mirky
# (of liquids) clouded as with sediment; dark or gloomy

# %%
desc4=['toxic','creamier','nutritious','lethal','traumatic','fishy','meteoric',
       'menial','murkier','squashed','gassier','thrown','woodier','darwinian',
       'buff','sundry','browner','phonetic','departmental','shrimpy','watered']

opin4=['motivational','tutorial','bearable','instructional','procurable','untold','statistical','transitional',
       'sufficient','tangential','ripened','litigious','god-awful','obtainable','social','hypnotic','harsher',
       'top-notch','short-term','evolutionary']


# If any word exists in testset, delete it and resample.
for w in desc4+opin4:
    if w in testset['word']:
        print(w)

desc_all=desc+desc2+desc3+desc4
opin_all=opin+opin2+opin3+opin4

    
word_type='adj'
trainset=[]
for w in desc_all:
    defn=adj.loc[adj.word==w,'text'].values[0]
    trainset.append((w,defn,0)) # 0: physical
for w in opin_all:
    defn=adj.loc[adj.word==w,'text'].values[0]
    trainset.append((w,defn,1)) # 1: mental
    
    
train4=pd.DataFrame()
train4['word'],train4['text'],train4['target']=list(zip(*(trainset)))

train4.to_csv('Data/train.v8.4.round4.csv')

# %% [markdown]
# ### Evaluate

# %%
pred=joblib.load('Data/pred.v8.4.1.round4') # load prediction result
assert pred.shape[0]==adj.shape[0]

# testset performance

pred_dict={}
for i,w in enumerate(adj['word'].tolist()):
    pred_dict[w]=pred[i]
    
    
testset['pred_score']=testset['word'].apply(lambda x: pred_dict[x])
testset['pred_label']=testset['pred_score'].apply(lambda x: 1 if x>0.5 else 0)

# positive::precision
print("positive::precision %.3f"%(testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.pred_label==1)].shape[0]))
print("positive::recall %.3f"%(testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.target==1)].shape[0]))


print("negative::precision %.3f"%(testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.pred_label==0)].shape[0]))
print("negative::recall %.3f"%(testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.target==0)].shape[0]))

pp=testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.pred_label==1)].shape[0]
pr=testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.target==1)].shape[0]

print("F1: %.2f"%(2*pp*pr/(pp+pr)))

np=testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.pred_label==0)].shape[0]
nr=testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.target==0)].shape[0]

print("N F1: %.2f"%(2*np*nr/(np+nr)))
# Out:
# positive::precision 0.508
# positive::recall 0.889
# negative::precision 0.892
# negative::recall 0.516
# F1: 0.65
# N F1: 0.65

# %% [markdown]
# ### RunTwoMore

# %% [markdown]
#     For another two runs, only show the prediction result over testset.

# %%
pred=joblib.load('Data/pred.v8.4.2.round4') # load prediction result
assert pred.shape[0]==adj.shape[0]

# testset performance

pred_dict={}
for i,w in enumerate(adj['word'].tolist()):
    pred_dict[w]=pred[i]
    
    
testset['pred_score']=testset['word'].apply(lambda x: pred_dict[x])
testset['pred_label']=testset['pred_score'].apply(lambda x: 1 if x>0.5 else 0)

# positive::precision
print("positive::precision %.3f"%(testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.pred_label==1)].shape[0]))
print("positive::recall %.3f"%(testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.target==1)].shape[0]))


print("negative::precision %.3f"%(testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.pred_label==0)].shape[0]))
print("negative::recall %.3f"%(testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.target==0)].shape[0]))

pp=testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.pred_label==1)].shape[0]
pr=testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.target==1)].shape[0]

print("F1: %.2f"%(2*pp*pr/(pp+pr)))

np=testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.pred_label==0)].shape[0]
nr=testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.target==0)].shape[0]

print("N F1: %.2f"%(2*np*nr/(np+nr)))
# Out:
# positive::precision 0.547
# positive::recall 0.806
# negative::precision 0.851
# negative::recall 0.625
# F1: 0.65
# N F1: 0.72

# %%
pred=joblib.load('Data/pred.v8.4.3.round4') # load prediction result
assert pred.shape[0]==adj.shape[0]

# testset performance

pred_dict={}
for i,w in enumerate(adj['word'].tolist()):
    pred_dict[w]=pred[i]
    
    
testset['pred_score']=testset['word'].apply(lambda x: pred_dict[x])
testset['pred_label']=testset['pred_score'].apply(lambda x: 1 if x>0.5 else 0)

# positive::precision
print("positive::precision %.3f"%(testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.pred_label==1)].shape[0]))
print("positive::recall %.3f"%(testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.target==1)].shape[0]))


print("negative::precision %.3f"%(testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.pred_label==0)].shape[0]))
print("negative::recall %.3f"%(testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.target==0)].shape[0]))

pp=testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.pred_label==1)].shape[0]
pr=testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.target==1)].shape[0]

print("F1: %.2f"%(2*pp*pr/(pp+pr)))

np=testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.pred_label==0)].shape[0]
nr=testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.target==0)].shape[0]

print("N F1: %.2f"%(2*np*nr/(np+nr)))
# Out:
# positive::precision 0.485
# positive::recall 0.917
# negative::precision 0.906
# negative::recall 0.453
# F1: 0.63
# N F1: 0.60

# %% [markdown]
# ## Iter5

# %% [markdown]
# ### Setup

# %%
pred=joblib.load('Data/pred.v8.4.1.round4') # load prediction result
assert pred.shape[0]==adj.shape[0]
labeled_words=train4['word'].tolist()

w_prob_map={}
for i,w in enumerate(adj['word'].tolist()):
    w_prob_map[w]=[1-pred[i].item(),pred[i].item()]
unlabeled_words=[ w for w in adj['word'].tolist() if w not in labeled_words]
cs=cal(labeled_words, unlabeled_words, acq_size, w_prob_map, neighK , fast_model)

# %%
for w,kl in cs:
    
    print(w)
    print(adj.loc[adj.word==w,'text'].values[0])
    print('\n')
# Out:
# reptilian
# of or relating to the class Reptilia
#
#
# peachy
# very good; of something resembling a peach in color
#
#
# yellowish
# of the color intermediate between green and orange in the color spectrum; of something resembling the color of an egg yolk
#
#
# rounded
# curving and somewhat round in shape rather than jagged
#
#
# bubbly
# emitting or filled with bubbles as from carbonation or fermentation; full of or showing high spirits
#
#
# pet
# preferred above all others and treated with partiality
#
#
# bubblier
# emitting or filled with bubbles as from carbonation or fermentation; full of or showing high spirits
#
#
# peachier
# very good; of something resembling a peach in color
#
#
# squishy
# easily squashed; resembling a sponge in having soft porous texture and compressibility
#
#
# floaty
# tending to float on a liquid or rise in air or gas
#
#
# nourishing
# of or providing nourishment
#
#
# underdone
# insufficiently cooked
#
#
# gnarly
# used of old persons or old trees; covered with knobs or knots
#
#
# leavened
# made light by aerating, as with yeast or baking powder; often used as a combining form
#
#
# electric
# using or providing or producing or transmitting or operated by electricity; (of a situation) exceptionally tense; affected by emotion as if by electricity; thrilling
#
#
# warped
# used especially of timbers or boards; bent out of shape usually by moisture
#
#
# composite
# consisting of separate interconnected parts; of or relating to or belonging to the plant family Compositae
#
#
# lessened
# impaired by diminution; decreased in severity; made less harsh
#
#
# grungy
# thickly covered with ingrained dirt or soot
#
#
# grayish
# of an achromatic color of any lightness intermediate between the extremes of white and black
#
#
# fledged
# (of birds) having developed feathers or plumage; often used in combination; (of an arrow) equipped with feathers
#
#
# crowded
# overfilled or compacted or concentrated
#
#
# golden-yellow
# of yellow tinged with gold
#
#
# cultivated
# (of land or fields) prepared for raising crops by plowing or fertilizing; no longer in the natural state; developed by human care and for human use; marked by refinement in taste and manners
#
#
# tacky
# (of a glutinous liquid such as paint) not completely dried and slightly sticky to the touch; tastelessly showy
#
#
# dark-brown
# of a color similar to that of wood or earth
#
#
# wavier
# (of hair) having waves; uneven by virtue of having wrinkles or waves
#
#
# darkened
# (of fabrics and paper) grown dark in color over time; become or made dark by lack of light
#
#
# creaky
# worn and broken down by hard use; having a rasping or grating sound; of or pertaining to arthritis
#
#
# suspended
# (of undissolved particles in a fluid) supported or kept from sinking or falling by buoyancy and without apparent attachment
#
#
# rare
# not widely known; especially valued for its uncommonness; recurring only at long intervals; not widely distributed; having low density; marked by an uncommon quality; especially superlative or extreme of its kind; -J.R.Lowell; (of meat) cooked a short time; still red inside
#
#
# pinkish-orange
# of orange tinged with pink
#
#
# ripe
# fully developed or matured and ready to be eaten or used; fully prepared or eager; most suitable or right for a particular purpose; at the highest point of development especially in judgment or knowledge; far along in time
#
#
# run-down
# worn and broken down by hard use; having the spring unwound
#
#
# cloudier
# lacking definite form or limits; - H.T.Moore; full of or covered with clouds; (of liquids) clouded as with sediment
#
#
# greyish
# of an achromatic color of any lightness intermediate between the extremes of white and black
#
#
# netted
# having open interstices or resembling a web
#
#
# skimmed
# used of milk and milk products from which the cream has been removed
#
#
# rarer
# not widely known; especially valued for its uncommonness; recurring only at long intervals; not widely distributed; having low density; marked by an uncommon quality; especially superlative or extreme of its kind; -J.R.Lowell; (of meat) cooked a short time; still red inside
#
#
# parasitic
# relating to or caused by parasites; of or pertaining to epenthesis; of plants or persons; having the nature or habits of a parasite or leech; living off another
#
#
# splashy
# characterized by water flying about haphazardly; marked by ostentation but often tasteless; covered with patches of bright color
#
#
# grainy
# composed of or covered with particles resembling meal in texture or consistency
#
#
# crystalised
# (used especially of fruits) preserved by coating with or allowing to absorb sugar; having both internal structure and external form of a crystal
#
#
# uppercase
# relating to capital letters which were kept in the top half of a compositor's type case
#
#
# grave
# dignified and somber in manner or character and committed to keeping promises; causing fear or anxiety by threatening great harm; of great gravity or crucial import; requiring serious thought
#
#
# blue-green
# of a bluish shade of green
#
#
# greenish-brown
# of brown tinged with green
#
#
# powdery
# consisting of fine particles; as if dulled in color with a sprinkling of powder
#
#
# gingery
# having a taste like that of ginger; (used especially of hair or fur) having a bright orange-brown color
#
#
# dingy
# thickly covered with ingrained dirt or soot; (of color) discolored by impurities; not bright and clear;  is often used in combination; causing dejection
#
#
# yellow-green
# of a color midway between yellow and green
#
#
# tackier
# (of a glutinous liquid such as paint) not completely dried and slightly sticky to the touch; tastelessly showy
#
#
# liked
# found pleasant or attractive; often used as a combining form
#
#
# congealed
# congealed into jelly; solidified by cooling
#
#
# grubby
# infested with grubs; thickly covered with ingrained dirt or soot
#
#
# comestible
# suitable for use as food
#
#
# mirky
# (of liquids) clouded as with sediment; dark or gloomy
#
#
# chitinous
# of or resembling chitin
#
#
# granular
# composed of or covered with particles resembling meal in texture or consistency; having a granular structure like that of chondrites
#
#
# draining
# having a debilitating effect
#
#
# softening
# having a softening or soothing effect especially to the skin
#
#
# capped
# used especially of front teeth having (artificial) crowns; covered as if with a cap or crown especially of a specified kind
#
#
# drinkable
# suitable for drinking
#
#
# acerbic
# sour or bitter in taste; harsh or corrosive in tone
#
#
# brackish
# distasteful and unpleasant; spoiled by mixture; slightly salty (especially from containing a mixture of seawater and fresh water)
#
#
# splashed
# (of a fluid) having been propelled about in flying drops or masses; covered with bright patches (often used in combination)
#
#
# murky
# (of liquids) clouded as with sediment; dark or gloomy
#
#
# dissoluble
# capable of dissolving
#
#
# swampy
# (of soil) soft and watery
#
#
# infrequent
# not frequent; not occurring regularly or at short intervals
#
#
# dustier
# covered with a layer of dust; lacking originality or spontaneity; no longer new
#
#
# grainier
# composed of or covered with particles resembling meal in texture or consistency
#
#
# bilious
# relating to or containing bile; suffering from or suggesting a liver disorder or gastric distress; irritable as if suffering from indigestion
#
#
# honeyed
# with honey added; pleasing to the ear
#
#
# fine-grained
# consisting of fine particles; dense or compact in structure or texture, as a wood composed of small-diameter cells
#
#
# spotty
# having spots or patches (small areas of contrasting color or texture); lacking consistency
#
#
# patched
# mended usually clumsily by covering a hole with a patch; having spots or patches (small areas of contrasting color or texture)
#
#
# concerted
# involving the joint activity of two or more
#
#
# patchy
# irregular or uneven in quality, texture, etc.
#
#
# golden-brown
# of brown tinged with gold
#
#
# non-poisonous
# not producing poison; safe to eat
#
#
# cloudy
# lacking definite form or limits; - H.T.Moore; full of or covered with clouds; (of liquids) clouded as with sediment
#
#
# blunted
# made dull or blunt
#
#
# carroty
# resembling the bright orange of the root of the carrot plant
#
#
# fishier
# of or relating to or resembling fish; not as expected
#
#
# splashier
# characterized by water flying about haphazardly; marked by ostentation but often tasteless; covered with patches of bright color
#
#
# orange-colored
# having the color of ripe oranges
#
#
# crustacean
# of or belonging to the class Crustacea
#
#
# chunkier
# like or containing small sticky lumps; short and thick; as e.g. having short legs and heavy musculature
#
#
# iron
# extremely robust
#
#
# garlicky
# relating to or tasting or smelling of garlic
#
#
# unsweet
# (of champagne) moderately dry; distasteful
#
#
# coarse-textured
# having surface roughness
#
#
# wheezy
# having a tone of a reed instrument; relating to breathing with a whistling sound
#
#
# lightheaded
# weak and likely to lose consciousness; lacking seriousness; given to frivolity
#
#
# reddish-brown
# of brown tinged with red
#
#
# astringent
# sour or bitter in taste; tending to draw together or constrict soft organic tissue
#
#
# covered
# overlaid or spread or topped with or enclosed within something; sometimes used as a combining form
#
#
# double
# having more than one decidedly dissimilar aspects or qualities; ; - R.W.Emerson; -Frederick Harrison; consisting of or involving two parts or components usually in pairs; twice as great or many; used of flowers having more than the usual number of petals in crowded or overlapping arrangements; used of homologous chromosomes associated in pairs in synapsis; large enough for two; having two meanings with intent to deceive
#
#
# shaggy
# used of hair; thick and poorly groomed; having a very rough nap or covered with hanging shags
#
#
# spoiled
# having the character or disposition harmed by pampering or oversolicitous attention; (of foodstuffs) not in an edible or usable condition
#
#
# impacted
# wedged or packed in together
#
#
# disconcerting
# causing an emotional disturbance; - Herb Caen
#
#
# caramel
# having the color of caramel; of a moderate yellow-brown
#
#
# shadowy
# filled with shade; lacking clarity or distinctness; lacking in substance; - W.A.Butler
#
#
# reddish-orange
# of orange tinged with red
#
#
# bay
# (used of animals especially a horse) of a moderate reddish-brown color
#
#
# pastier
# resembling paste in color; pallid; having the sticky properties of an adhesive
#
#
# spaced
# spaced apart; arranged with spaces between; often used as a combining form
#
#
# octagonal
# of or relating to or shaped like an octagon
#
#
# purplish
# of a color intermediate between red and blue
#
#
# yellow-brown
# of a medium to dark brownish yellow color
#
#
# x
# being one more than nine
#
#
# orange-brown
# of brown tinged with orange
#
#
# effervescent
# used of wines and waters; charged naturally or artificially with carbon dioxide; (of a liquid) giving off bubbles; marked by high spirits or excitement
#
#
# fine-textured
# having a smooth, fine-grained structure
#
#
# constipated
# have difficult or incomplete or infrequent evacuation of the bowels
#
#
# nonspecific
# not caused by a specific agent; used also of staining in making microscope slides
#
#
# narcotic
# of or relating to or designating narcotics; inducing stupor or narcosis; inducing mental lethargy
#
#
# uncouth
# lacking refinement or cultivation or taste

# %%
desc5=['reptilian','rounded','squishy','floaty','nourishing','underdone','gnarly',
       'leavened','electric','warped','grungy','grayish','fledged','crowded',
       'golden-yellow','cultivated','tacky','dark-brown','wavier','darkened','creaky']

opin5=['pet','composite','lessened','rare','grave','liked','infrequent','blunted',
       'lightheaded','spoiled','disconcerting','spaced','uncouth']


# If any word exists in testset, delete it and resample.
for w in desc5+opin5:
    if w in testset['word']:
        print(w)

desc_all=desc+desc2+desc3+desc4+desc5
opin_all=opin+opin2+opin3+opin4+opin5

    
word_type='adj'
trainset=[]
for w in desc_all:
    defn=adj.loc[adj.word==w,'text'].values[0]
    trainset.append((w,defn,0)) # 0: physical
for w in opin_all:
    defn=adj.loc[adj.word==w,'text'].values[0]
    trainset.append((w,defn,1)) # 1: mental
    
    
train5=pd.DataFrame()
train5['word'],train5['text'],train5['target']=list(zip(*(trainset)))

train5.to_csv('Data/train.v8.5.round5.csv')

# %% [markdown]
# ### Evaluate

# %%
pred=joblib.load('Data/pred.v8.5.1.round5') # load prediction result
assert pred.shape[0]==adj.shape[0]

# testset performance

pred_dict={}
for i,w in enumerate(adj['word'].tolist()):
    pred_dict[w]=pred[i]
    
    
testset['pred_score']=testset['word'].apply(lambda x: pred_dict[x])
testset['pred_label']=testset['pred_score'].apply(lambda x: 1 if x>0.5 else 0)

# positive::precision
print("positive::precision %.3f"%(testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.pred_label==1)].shape[0]))
print("positive::recall %.3f"%(testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.target==1)].shape[0]))


print("negative::precision %.3f"%(testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.pred_label==0)].shape[0]))
print("negative::recall %.3f"%(testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.target==0)].shape[0]))

pp=testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.pred_label==1)].shape[0]
pr=testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.target==1)].shape[0]

print("F1: %.2f"%(2*pp*pr/(pp+pr)))

np=testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.pred_label==0)].shape[0]
nr=testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.target==0)].shape[0]

print("N F1: %.2f"%(2*np*nr/(np+nr)))
# Out:
# positive::precision 0.538
# positive::recall 0.972
# negative::precision 0.971
# negative::recall 0.531
# F1: 0.69
# N F1: 0.69

# %% [markdown]
# ###  RunTwoMore

# %% [markdown]
#     For another two runs, only show the prediction result over testset.

# %%
pred=joblib.load('Data/pred.v8.5.2.round5') # load prediction result
assert pred.shape[0]==adj.shape[0]

# testset performance

pred_dict={}
for i,w in enumerate(adj['word'].tolist()):
    pred_dict[w]=pred[i]
    
    
testset['pred_score']=testset['word'].apply(lambda x: pred_dict[x])
testset['pred_label']=testset['pred_score'].apply(lambda x: 1 if x>0.5 else 0)

# positive::precision
print("positive::precision %.3f"%(testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.pred_label==1)].shape[0]))
print("positive::recall %.3f"%(testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.target==1)].shape[0]))


print("negative::precision %.3f"%(testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.pred_label==0)].shape[0]))
print("negative::recall %.3f"%(testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.target==0)].shape[0]))

pp=testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.pred_label==1)].shape[0]
pr=testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.target==1)].shape[0]

print("F1: %.2f"%(2*pp*pr/(pp+pr)))

np=testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.pred_label==0)].shape[0]
nr=testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.target==0)].shape[0]

print("N F1: %.2f"%(2*np*nr/(np+nr)))
# Out:
# positive::precision 0.548
# positive::recall 0.944
# negative::precision 0.947
# negative::recall 0.562
# F1: 0.69
# N F1: 0.71

# %%
pred=joblib.load('Data/pred.v8.5.3.round5') # load prediction result
assert pred.shape[0]==adj.shape[0]

# testset performance

pred_dict={}
for i,w in enumerate(adj['word'].tolist()):
    pred_dict[w]=pred[i]
    
    
testset['pred_score']=testset['word'].apply(lambda x: pred_dict[x])
testset['pred_label']=testset['pred_score'].apply(lambda x: 1 if x>0.5 else 0)

# positive::precision
print("positive::precision %.3f"%(testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.pred_label==1)].shape[0]))
print("positive::recall %.3f"%(testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.target==1)].shape[0]))


print("negative::precision %.3f"%(testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.pred_label==0)].shape[0]))
print("negative::recall %.3f"%(testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.target==0)].shape[0]))

pp=testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.pred_label==1)].shape[0]
pr=testset.loc[(testset.pred_label==1)&(testset.target==1)].shape[0]/testset.loc[(testset.target==1)].shape[0]

print("F1: %.2f"%(2*pp*pr/(pp+pr)))

np=testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.pred_label==0)].shape[0]
nr=testset.loc[(testset.pred_label==0)&(testset.target==0)].shape[0]/testset.loc[(testset.target==0)].shape[0]

print("N F1: %.2f"%(2*np*nr/(np+nr)))
# Out:
# positive::precision 0.525
# positive::recall 0.889
# negative::precision 0.897
# negative::recall 0.547
# F1: 0.66
# N F1: 0.68

# %% [markdown]
# # Summary

# %% [markdown]
#     Iter2: Annotate 50 words where we pick 20-20 for training.
#     Iter3: Annotate 120 words where we pick 5(pos)-20 for training. Could NOT find enough positive samples.
#     Iter4: Annotate 80 words where we pick 20-20 for training.
#     Iter5: Annotate 120 words where we pick 13(pos)-20 for training. Could NOT find enough positive samples.
#     Annotate >120words/iter. This method needs to annotate more samples than HighEntropy/CORESET/RANDOM.
#
#     For classification performance, CAL doesn't beat HighEntropy and CORESET, but better than Random. The reason might be the size of the labeled words is too small to guarantee that the nearest neighors to the target unlabeled word are not similar in semantics. That's to say, the selected words are not valid contrastive samples.
